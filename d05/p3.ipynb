# %%
import numpy as np
filename = '1.npy'
data = np.load(filename)

# %%
print(data)
# Out:
# [[-10.          18.3953017 ]
#  [ -9.31034483  14.67879813]
#  [ -8.62068966  13.62407249]
#  [ -7.93103448  13.52377377]
#  [ -7.24137931   9.063285  ]
#  [ -6.55172414   9.54930112]
#  [ -5.86206897  15.35225611]
#  [ -5.17241379   6.07518042]
#  [ -4.48275862  10.89413544]
#  [ -3.79310345   6.70877808]
#  [ -3.10344828   8.40736266]
#  [ -2.4137931   11.02840309]
#  [ -1.72413793   8.21510309]
#  [ -1.03448276  -1.38016606]
#  [ -0.34482759   0.30091641]
#  [  0.34482759  -2.99363972]
#  [  1.03448276  -0.77523302]
#  [  1.72413793   1.85095408]
#  [  2.4137931   -4.88528709]
#  [  3.10344828   0.85234986]
#  [  3.79310345  -5.42064117]
#  [  4.48275862  -0.47021073]
#  [  5.17241379  -2.33400087]
#  [  5.86206897  -6.8873433 ]
#  [  6.55172414 -14.57674249]
#  [  7.24137931  -5.89703259]
#  [  7.93103448 -13.57661885]
#  [  8.62068966  -6.59371351]
#  [  9.31034483 -11.44163018]
#  [ 10.         -13.00623188]]

# %%
X = data[:, 0].reshape(-1, 1)
y = data[:, 1]

# %%
print(X)
# Out:
# [[-10.        ]
#  [ -9.31034483]
#  [ -8.62068966]
#  [ -7.93103448]
#  [ -7.24137931]
#  [ -6.55172414]
#  [ -5.86206897]
#  [ -5.17241379]
#  [ -4.48275862]
#  [ -3.79310345]
#  [ -3.10344828]
#  [ -2.4137931 ]
#  [ -1.72413793]
#  [ -1.03448276]
#  [ -0.34482759]
#  [  0.34482759]
#  [  1.03448276]
#  [  1.72413793]
#  [  2.4137931 ]
#  [  3.10344828]
#  [  3.79310345]
#  [  4.48275862]
#  [  5.17241379]
#  [  5.86206897]
#  [  6.55172414]
#  [  7.24137931]
#  [  7.93103448]
#  [  8.62068966]
#  [  9.31034483]
#  [ 10.        ]]

# %%
print(y)
# Out:
# [ 18.3953017   14.67879813  13.62407249  13.52377377   9.063285
#    9.54930112  15.35225611   6.07518042  10.89413544   6.70877808
#    8.40736266  11.02840309   8.21510309  -1.38016606   0.30091641
#   -2.99363972  -0.77523302   1.85095408  -4.88528709   0.85234986
#   -5.42064117  -0.47021073  -2.33400087  -6.8873433  -14.57674249
#   -5.89703259 -13.57661885  -6.59371351 -11.44163018 -13.00623188]

# %%
from sklearn.linear_model import LinearRegression
# инициализация модели и обучение
regressor = LinearRegression()
regressor.fit(X, y)

# вычисление коэффициента детерминации
r2 = regressor.score(X, y)

print('R^2 =', r2)
# Out:
# R^2 = 0.8804493891389981

# %%
filename = '2.npy'
data = np.load(filename)
X = data[:, 0].reshape(-1, 1)
y = data[:, 1]
# инициализация модели и обучение
regressor = LinearRegression()
regressor.fit(X, y)

# вычисление коэффициента детерминации
r2 = regressor.score(X, y)

print('R^2 =', r2)
# Out:
# R^2 = 0.6049683606213805

# %%
filename = '3.npy'
data = np.load(filename)
X = data[:, 0].reshape(-1, 1)
y = data[:, 1]
# инициализация модели и обучение
regressor = LinearRegression()
regressor.fit(X, y)

# вычисление коэффициента детерминации
r2 = regressor.score(X, y)

print('R^2 =', r2)
# Out:
# R^2 = 0.9436398449037311

# %%
filename = '4.npy'
data = np.load(filename)
X = data[:, 0].reshape(-1, 1)
y = data[:, 1]
# инициализация модели и обучение
regressor = LinearRegression()
regressor.fit(X, y)

# вычисление коэффициента детерминации
r2 = regressor.score(X, y)

print('R^2 =', r2)
# Out:
# R^2 = 0.18606626924708636

# %%
filename = '5.npy'
data = np.load(filename)
X = data[:, 0].reshape(-1, 1)
y = data[:, 1]
# инициализация модели и обучение
regressor = LinearRegression()
regressor.fit(X, y)

# вычисление коэффициента детерминации
r2 = regressor.score(X, y)

print('R^2 =', r2)
# Out:
# R^2 = 0.848322909283604
